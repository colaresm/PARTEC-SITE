# %%
import pandas as pd

# %%
confirmedGlobal=pd.read_csv('labs.csv',encoding='utf-8',na_values=None) 
df=confirmedGlobal[confirmedGlobal].transpose().iloc[4:].reset_index()
df.columns=['Dates','CumulatedValues']
allData=[]
for i in range(df.shape[0]):
    temp=df.loc[i]
    allData.append(dict(temp))
context= {'data':allData}

# %%
context
# Out:
# {'data': [{'Dates': '1/22/20', 'CumulatedValues': 0},
#   {'Dates': '1/23/20', 'CumulatedValues': 0},
#   {'Dates': '1/24/20', 'CumulatedValues': 0},
#   {'Dates': '1/25/20', 'CumulatedValues': 0},
#   {'Dates': '1/26/20', 'CumulatedValues': 0},
#   {'Dates': '1/27/20', 'CumulatedValues': 0},
#   {'Dates': '1/28/20', 'CumulatedValues': 0},
#   {'Dates': '1/29/20', 'CumulatedValues': 0},
#   {'Dates': '1/30/20', 'CumulatedValues': 1},
#   {'Dates': '1/31/20', 'CumulatedValues': 1},
#   {'Dates': '2/1/20', 'CumulatedValues': 1},
#   {'Dates': '2/2/20', 'CumulatedValues': 2},
#   {'Dates': '2/3/20', 'CumulatedValues': 3},
#   {'Dates': '2/4/20', 'CumulatedValues': 3},
#   {'Dates': '2/5/20', 'CumulatedValues': 3},
#   {'Dates': '2/6/20', 'CumulatedValues': 3},
#   {'Dates': '2/7/20', 'CumulatedValues': 3},
#   {'Dates': '2/8/20', 'CumulatedValues': 3},
#   {'Dates': '2/9/20', 'CumulatedValues': 3},
#   {'Dates': '2/10/20', 'CumulatedValues': 3},
# ...

# %%
df=confirmedGlobal[confirmedGlobal].transpose().iloc[4:].reset_index()
df.columns=['Site','Site']
for i in range(df.shape[0]):
        temp=df.loc[i]
        allData.append(dict(temp))
        context= {'data':allData}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-b21ba414bf29> in <module>
# ----> 1 df=confirmedGlobal[confirmedGlobal].transpose().iloc[4:].reset_index()
#       2 df.columns=['Site','Site']
#       3 for i in range(df.shape[0]):
#       4         temp=df.loc[i]
#       5         allData.append(dict(temp))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2785         # Do we have a (boolean) DataFrame?
#    2786         if isinstance(key, DataFrame):
# -> 2787             return self.where(key)
#    2788
#    2789         # Do we have a (boolean) 1d indexer?
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    8919         other = com.apply_if_callable(other, self)
#    8920         return self._where(
# ...
